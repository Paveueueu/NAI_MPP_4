# %%
from main import k_means
k_means("data/input2", 3)
# Out:
# Loading points...
# Loaded 119 points
#
# Iteration 0
# Centroid [7.6, 3.1] ----- Points [[8.8, 3.1], [7.3, 2.6], [7.0, 4.7], [8.5, 3.2], [3.9, 3.0], [8.3, 4.1], [4.1, 3.0], [7.0, 2.8], [7.3, 2.3], [9.8, 3.4], [8.0, 6.0], [8.3, 3.2], [7.7, 6.1], [9.2, 3.9], [7.5, 4.6], [7.6, 3.1], [9.5, 6.8], [4.2, 2.7], [7.7, 4.5], [7.9, 4.0]]
# 	dist=94.50999999999999
# ...

# %%
k_means("data/input3", 4)
# Out:
# Loading points...
# Loaded 100 points
#
# Iteration 0
# Centroid [4.4, 3.0, 9.6] ----- Points [[4.4, 3.0, 9.6], [8.1, 3.8, 8.9], [3.3, 1.2, 6.2], [6.4, 4.2, 10.0], [1.9, 4.6, 9.8], [0.6, 3.1, 7.6], [3.2, 6.4, 8.2], [4.3, 2.3, 8.4], [4.5, 1.1, 7.6], [9.6, 2.4, 9.4], [3.7, 2.1, 5.7], [4.7, 0.7, 5.9], [6.7, 2.3, 9.0], [2.2, 1.2, 8.3], [7.0, 0.5, 9.0], [3.6, 3.8, 9.7], [4.6, 3.8, 9.3], [4.6, 1.5, 9.0], [0.3, 1.1, 5.4], [1.4, 1.3, 6.5], [0.4, 7.0, 10.0], [2.1, 2.8, 6.0], [4.6, 0.2, 7.6], [0.4, 3.9, 9.7], [4.3, 7.0, 9.0], [1.6, 4.1, 7.2], [0.0, 2.4, 4.7], [2.1, 4.5, 5.7], [2.8, 6.3, 7.0], [1.6, 2.7, 9.9]]
# 	dist=449.86
# ...

# %%
k_means("data/input4", 5)
# Out:
# Loading points...
# Loaded 120 points
#
# Iteration 0
# Centroid [7.8, 4.5, 8.4, 3.6] ----- Points [[6.7, 2.9, 8.7, 6.8], [7.8, 4.5, 8.4, 3.6], [8.4, 0.3, 4.5, 6.2], [8.8, 6.9, 7.7, 0.6], [8.9, 2.0, 4.1, 6.9], [7.7, 3.7, 9.2, 9.3], [7.6, 7.3, 2.7, 6.5], [7.7, 1.2, 2.7, 9.1], [9.9, 6.8, 1.1, 7.1], [4.1, 6.3, 2.0, 9.0], [5.5, 7.2, 8.7, 6.7], [6.2, 3.2, 8.8, 0.3], [7.9, 9.7, 9.3, 6.3], [7.3, 1.2, 7.3, 5.8], [8.7, 6.3, 6.4, 6.9], [5.7, 5.3, 9.6, 9.6], [4.3, 7.0, 6.3, 5.3], [9.8, 3.5, 9.0, 8.5], [7.3, 6.1, 3.3, 5.7], [9.1, 6.0, 5.6, 2.9], [7.4, 9.7, 6.4, 9.2], [7.6, 2.4, 3.6, 8.4], [8.2, 9.3, 0.3, 9.7], [8.5, 8.5, 0.9, 9.2], [5.7, 5.9, 8.4, 1.2], [7.1, 9.8, 9.3, 6.5], [9.9, 8.0, 6.7, 0.8], [6.2, 3.2, 8.8, 6.9], [7.1, 5.9, 1.7, 8.5], [4.4, 6.1, 9.8, 0.5], [6.3, 6.5, 6.6, 2.0], [5.6, 8.0, 9.7, 6.8], [5.4, 4.4, 9.5, 7.2], [7.1, 1.3, 3.4, 8.0]]
# 	dist=1326.6399999999999
# ...
